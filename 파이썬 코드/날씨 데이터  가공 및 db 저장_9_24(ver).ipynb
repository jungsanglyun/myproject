# %%
#서울 부산 대구 광주 대전 데이터 저장
#이전년도 데이터 종합

import csv
from dateutil.relativedelta import relativedelta
from datetime import datetime
from nltk.tokenize import word_tokenize 
import os, shutil
import cx_Oracle
import os

now = datetime.now()
today_str=str(now)
today_day_and_time=[]
today_day_and_time=word_tokenize(today_str)
today_day=today_day_and_time[0].split('-')

year=today_day[0] # 현재년
month=today_day[1]# 현재월
day=today_day[2]# 현재일


before_one_year = now - relativedelta(years=1)

before_today_str=str(before_one_year)
before_day_and_time=[]
before_day_and_time=word_tokenize(before_today_str)
beforey_day=before_day_and_time[0].split('-')

before_year=beforey_day[0]# 저번년
before_month=beforey_day[1]# 저번월
before_day=beforey_day[2]# 저번일

weather_code={'weather_01':'기온','weather_02':'강수량','weather_03':'바람'}
loacation_code={'loacation_01':'서울','loacation_02':'부산','loacation_03':'대구','location_05':'광주','location_06':'대전'}

LOCATION = r"C:\\instantclient-basic-windows.x64-19.11.0.0.0dbru\\instantclient_19_11" # 여러분들의 instantclient 가 있는 경로, \표시는 두개로 써줘야함
conn = cx_Oracle.connect("waap", "12345", "localhost:1521/xe") # 여러분들의 접속 이름, 비밀번호, 호스트이름, 포트, sid


for l in range(2):
    if l == 0:

        for p in loacation_code:
            
            #기온 강수량 바람 순서

            # 기온 데이터 타이틀['지점번호', '지점명', '일시', '평균기온(℃)', '최고기온(℃)', '최저기온(℃)']
            #이전 데이터 가공
            #-------------------------------------------------!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
            loacation_name=str(loacation_code[p])
            f2 = open(before_year+loacation_name+'기온.csv') # 이전년도 기온.csv
            
            temperature_data1=csv.reader(f2)
            header=next(temperature_data1)
            cnt=0
            temperature_realdata1=[]
            for row in temperature_data1:
                cnt+=1
                if (cnt >11):
                    temperature_realdata1.append(row)

            # 데이터에서 \t 문자열 제거
            #-------------------------------------------------

                    characters = "\t"
                    try:
                        string = row[0]
                    except IndexError:
                        continue 
                    for x in range(len(characters)):
                    # string = string.replace(characters[x],"")# \t 삭제한 row[0] 을 string 변수에 저장
                        string = "0"
                        cnt_list=cnt-12        #temperature_realdata1[0][0]을 자동으로 카운트해주기 위해
                
                        temperature_realdata1[cnt_list][0]=string #temperature_realdata1[n][0]에 있는 리스트 요소를 string으로 바꾸기 위함 
            f2.close()
            #__________________________________________________  

            # 필요한 타이틀만 남겨두기
            #-------------------------------------------------
            cnt_1=0

            for p in temperature_realdata1:

                try:
                    del temperature_realdata1[cnt_1][5]
                        
                except IndexError:
                    continue
                cnt_1+=1


            cnt_1=0
            cnt_2=7

            for p in temperature_realdata1:
                for x in range(2):
                    try:
                        del temperature_realdata1[cnt_1][cnt_2]
                        
                    except IndexError:
                        continue
                    
                    cnt_2-=1
                cnt_2=7
                cnt_1+=1

            cnt_1=0   

            for p in temperature_realdata1:

                try:
                    del temperature_realdata1[cnt_1][0]
                        
                except IndexError:
                    continue
                cnt_1+=1

            #__________________________________________________ 

            # 저장된 데이터에서 비어있는 쓰레기값 제거
            #-------------------------------------------------
            lendata=len(temperature_realdata1)-11

            for p1 in range(11):
                try:
                    del temperature_realdata1[lendata]
                except IndexError:
                        continue


            #===============================================================================================================================
            #강수량

            # 강수량 데이터 타이틀['지점번호', '지점명', '일시', '강수량(mm)']

            #이전 데이터 가공
            #-------------------------------------------------!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
            f3 = open(before_year+loacation_name+'강수량.csv') # 이전년도 바람.csv
            rain_data1=csv.reader(f3)
            header=next(rain_data1)
            cnt=0
            rain_realdata1=[]
            for row in rain_data1:
                cnt+=1
                if (cnt >12):                
                    rain_realdata1.append(row)
            # 데이터에서 \t 문자열 제거
            #-------------------------------------------------
                    characters = "\t"
                    try:
                        string = row[0]
                    except IndexError:
                        continue 
                    for x in range(len(characters)):
                        string = string.replace(characters[x],"")# \t 삭제한 row[0] 을 string 변수에 저장
                        
                        cnt_list=cnt-13          #rain_realdata1[0][0]을 자동으로 카운트해주기 위해
                
                        rain_realdata1[cnt_list][0]=string #rain_realdata1[n][0]에 있는 리스트 요소를 string으로 바꾸기 위함 
                        try:
                            if rain_realdata1[cnt_list][3]=='':
                                rain_realdata1[cnt_list][3]='0.0'
                        except IndexError:
                            continue 
            f3.close()
                        

            #__________________________________________________   

            # 필요한 타이틀만 남겨두기
            #-------------------------------------------------
            cnt_1=0
            cnt_2=5

            for p in rain_realdata1:
                for x in range(2):
                    try:
                        del rain_realdata1[cnt_1][cnt_2]
                    except IndexError:
                        continue
                    cnt_2-=1
                cnt_2=5
                cnt_1+=1
            cnt_1=0   

            for p in rain_realdata1:

                try:
                    del rain_realdata1[cnt_1][0]
                        
                except IndexError:
                    continue
                cnt_1+=1

            cnt_1=0
            for p in rain_realdata1:

                try:
                    del rain_realdata1[cnt_1][0]
                    del rain_realdata1[cnt_1][0]   
                except IndexError:
                    continue
                cnt_1+=1
            #__________________________________________________   

            # 저장된 데이터에서 비어있는 쓰레기값 제거
            #-------------------------------------------------

            lendata=len(rain_realdata1)-9

            for p1 in range(9):
                try:
                    del rain_realdata1[lendata]
                except IndexError:
                        continue

                        
            #===============================================================================================================================
            #바람

            # 바람 데이터 타이틀['지점번호', '지점명', '일시', '평균풍속(m/s)', '최대풍속(m/s)']

            #이전 데이터 가공
            #-------------------------------------------------!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
            f5 = open(before_year+loacation_name+'바람.csv') # 이전년도 바람.csv
            wind_data1=csv.reader(f5)
            header=next(wind_data1)
            cnt=0
            wind_realdata1=[]
            for row in wind_data1:
                cnt+=1
                if (cnt >15):
                    wind_realdata1.append(row)
            # 데이터에서 \t 문자열 제거
            #-------------------------------------------------
                    characters = "\t"
                    try:
                        string = row[0]
                    except IndexError:
                        continue 
                    for x in range(len(characters)):
                        string = string.replace(characters[x],"")# \t 삭제한 row[0] 을 string 변수에 저장
                        
                        cnt_list=cnt-16            #wind_realdata1[0][0]을 자동으로 카운트해주기 위해
                
                        wind_realdata1[cnt_list][0]=string #wind_realdata1[n][0]에 있는 리스트 요소를 string으로 바꾸기 위함 
            f5.close()
            #__________________________________________________   

            # 필요한 타이틀만 남겨두기
            #-------------------------------------------------
            cnt_1=0
            cnt_2=9
            for p in wind_realdata1:
                for x in range(5):
                    try:
                        del wind_realdata1[cnt_1][cnt_2]
                    except IndexError:
                        continue
                    cnt_2-=1
                cnt_2=9
                cnt_1+=1
                
            cnt_1=0   

            for p in wind_realdata1:

                try:
                    del wind_realdata1[cnt_1][0]
                        
                except IndexError:
                    continue
                cnt_1+=1
                
            cnt_1=0
            
            for p in wind_realdata1:

                try:
                    del wind_realdata1[cnt_1][0]
                    del wind_realdata1[cnt_1][0]   
                except IndexError:
                    continue
                cnt_1+=1
            #__________________________________________________   

            # 저장된 데이터에서 비어있는 쓰레기값 제거
            #-------------------------------------------------
            lendata=len(wind_realdata1)-7

            for p1 in range(7):
                try:
                    del wind_realdata1[lendata]
                except IndexError:
                        continue


            sum_realdata1= [[0 for col in range(8)] for row in range(len(temperature_realdata1))]
        
            

            cnt_1=0

            for p in sum_realdata1: 
                for z in range(8):
                    if z<5:
                        sum_realdata1[cnt_1][z]=temperature_realdata1[cnt_1][z]
                    elif z==5:
                        sum_realdata1[cnt_1][z]=rain_realdata1[cnt_1][z-z]
                    elif z==6:
                        sum_realdata1[cnt_1][z]=wind_realdata1[cnt_1][z-z]
                    else:
                        sum_realdata1[cnt_1][z]=wind_realdata1[cnt_1][z-(z-1)]
                cnt_1+=1

        
            cnt_1=0
            z=0

            
        
            
            if loacation_name =='서울':
                
                sum_data1= [[0 for col in range(8)] for row in range(len(temperature_realdata1))]
                
                for p in sum_data1: 
                    for z in range(8):
                        
                        try:
                            sum_data1[cnt_1][0]=sum_realdata1[cnt_1][1]
                            sum_data1[cnt_1][1]=sum_realdata1[cnt_1][0]
                        except IndexError:
                                continue
                        if z>=2:
                            sum_data1[cnt_1][z]=sum_realdata1[cnt_1][z]

                    cnt_1+=1
                
            elif loacation_name =='부산':
                
                sum_data2= [[0 for col in range(8)] for row in range(len(temperature_realdata1))]
                p=0
                z=0
                cnt_1=0
                for p in sum_data2: 
                    for z in range(8):
                        
                        try:
                            sum_data2[cnt_1][0]=sum_realdata1[cnt_1][1]
                            sum_data2[cnt_1][1]=sum_realdata1[cnt_1][0]
                        except IndexError:
                                continue
                        if z>=2:
                            sum_data2[cnt_1][z]=sum_realdata1[cnt_1][z]

                    cnt_1+=1
                

                

            elif loacation_name =='대구':
                sum_data3= [[0 for col in range(8)] for row in range(len(temperature_realdata1))]
                p=0
                z=0
                cnt_1=0
                for p in sum_data3: 
                    for z in range(8):
                        
                        try:
                            sum_data3[cnt_1][0]=sum_realdata1[cnt_1][1]
                            sum_data3[cnt_1][1]=sum_realdata1[cnt_1][0]
                        except IndexError:
                                continue
                        if z>=2:
                            sum_data3[cnt_1][z]=sum_realdata1[cnt_1][z]

                    cnt_1+=1


            elif loacation_name =='광주':
                sum_data5= [[0 for col in range(8)] for row in range(len(temperature_realdata1))]
                p=0
                z=0
                cnt_1=0
                for p in sum_data5: 
                    for z in range(8):
                        
                        try:
                            sum_data5[cnt_1][0]=sum_realdata1[cnt_1][1]
                            sum_data5[cnt_1][1]=sum_realdata1[cnt_1][0]
                        except IndexError:
                                continue
                        if z>=2:
                            sum_data5[cnt_1][z]=sum_realdata1[cnt_1][z]

                    cnt_1+=1

            elif loacation_name =='대전':
                sum_data6= [[0 for col in range(8)] for row in range(len(temperature_realdata1))]
                p=0
                z=0
                cnt_1=0
                for p in sum_data6: 
                    for z in range(8):
                        
                        try:
                            sum_data6[cnt_1][0]=sum_realdata1[cnt_1][1]
                            sum_data6[cnt_1][1]=sum_realdata1[cnt_1][0]
                        except IndexError:
                                continue
                        if z>=2:
                            sum_data6[cnt_1][z]=sum_realdata1[cnt_1][z]

                    cnt_1+=1

 
            
    if l == 1:
        p=0
        for p in loacation_code:
    
            #기온 강수량 바람 순서

            # 기온 데이터 타이틀['지점번호', '지점명', '일시', '평균기온(℃)', '최고기온(℃)', '최저기온(℃)']
            #이전 데이터 가공
            #-------------------------------------------------!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
            loacation_name=str(loacation_code[p])
            f1 = open(year+loacation_name+'기온.csv') # 이전년도 기온.csv
            
            temperature_data1=csv.reader(f1)
            header=next(temperature_data1)
            cnt=0
            temperature_realdata1=[]
            for row in temperature_data1:
                cnt+=1
                if (cnt >11):
                    temperature_realdata1.append(row)

            # 데이터에서 \t 문자열 제거
            #-------------------------------------------------

                    characters = "\t"
                    try:
                        string = row[0]
                    except IndexError:
                        continue 
                    for x in range(len(characters)):
                    # string = string.replace(characters[x],"")# \t 삭제한 row[0] 을 string 변수에 저장
                        string = "0"
                        cnt_list=cnt-12        #temperature_realdata1[0][0]을 자동으로 카운트해주기 위해
                
                        temperature_realdata1[cnt_list][0]=string #temperature_realdata1[n][0]에 있는 리스트 요소를 string으로 바꾸기 위함 
            f1.close()
            #__________________________________________________  

            # 필요한 타이틀만 남겨두기
            #-------------------------------------------------
            cnt_1=0

            for p in temperature_realdata1:

                try:
                    del temperature_realdata1[cnt_1][5]
                        
                except IndexError:
                    continue
                cnt_1+=1


            cnt_1=0
            cnt_2=7

            for p in temperature_realdata1:
                for x in range(2):
                    try:
                        del temperature_realdata1[cnt_1][cnt_2]
                        
                    except IndexError:
                        continue
                    
                    cnt_2-=1
                cnt_2=7
                cnt_1+=1

            cnt_1=0   

            for p in temperature_realdata1:

                try:
                    del temperature_realdata1[cnt_1][0]
                        
                except IndexError:
                    continue
                cnt_1+=1

            #__________________________________________________ 

            # 저장된 데이터에서 비어있는 쓰레기값 제거
            #-------------------------------------------------
            lendata=len(temperature_realdata1)-11

            for p1 in range(11):
                try:
                    del temperature_realdata1[lendata]
                except IndexError:
                        continue


            #===============================================================================================================================
            #강수량

            # 강수량 데이터 타이틀['지점번호', '지점명', '일시', '강수량(mm)']

            #이전 데이터 가공
            #-------------------------------------------------!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
            f4 = open(year+loacation_name+'강수량.csv') # 이전년도 바람.csv
            rain_data1=csv.reader(f4)
            header=next(rain_data1)
            cnt=0
            rain_realdata1=[]
            for row in rain_data1:
                cnt+=1
                if (cnt >12):                
                    rain_realdata1.append(row)
            # 데이터에서 \t 문자열 제거
            #-------------------------------------------------
                    characters = "\t"
                    try:
                        string = row[0]
                    except IndexError:
                        continue 
                    for x in range(len(characters)):
                        string = string.replace(characters[x],"")# \t 삭제한 row[0] 을 string 변수에 저장
                        
                        cnt_list=cnt-13          #rain_realdata1[0][0]을 자동으로 카운트해주기 위해
                
                        rain_realdata1[cnt_list][0]=string #rain_realdata1[n][0]에 있는 리스트 요소를 string으로 바꾸기 위함 
                        try:
                            if rain_realdata1[cnt_list][3]=='':
                                rain_realdata1[cnt_list][3]='0.0'
                        except IndexError:
                            continue 
            f4.close()
                        

            #__________________________________________________   

            # 필요한 타이틀만 남겨두기
            #-------------------------------------------------
            cnt_1=0
            cnt_2=5

            for p in rain_realdata1:
                for x in range(2):
                    try:
                        del rain_realdata1[cnt_1][cnt_2]
                    except IndexError:
                        continue
                    cnt_2-=1
                cnt_2=5
                cnt_1+=1
            cnt_1=0   

            for p in rain_realdata1:

                try:
                    del rain_realdata1[cnt_1][0]
                        
                except IndexError:
                    continue
                cnt_1+=1

            cnt_1=0
            for p in rain_realdata1:

                try:
                    del rain_realdata1[cnt_1][0]
                    del rain_realdata1[cnt_1][0]   
                except IndexError:
                    continue
                cnt_1+=1
            #__________________________________________________   

            # 저장된 데이터에서 비어있는 쓰레기값 제거
            #-------------------------------------------------

            lendata=len(rain_realdata1)-9

            for p1 in range(9):
                try:
                    del rain_realdata1[lendata]
                except IndexError:
                        continue

                        
            #===============================================================================================================================
            #바람

            # 바람 데이터 타이틀['지점번호', '지점명', '일시', '평균풍속(m/s)', '최대풍속(m/s)']

            #이전 데이터 가공
            #-------------------------------------------------!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
            f6 = open(year+loacation_name+'바람.csv') # 이전년도 바람.csv
            wind_data1=csv.reader(f6)
            header=next(wind_data1)
            cnt=0
            wind_realdata1=[]
            for row in wind_data1:
                cnt+=1
                if (cnt >15):
                    wind_realdata1.append(row)
            # 데이터에서 \t 문자열 제거
            #-------------------------------------------------
                    characters = "\t"
                    try:
                        string = row[0]
                    except IndexError:
                        continue 
                    for x in range(len(characters)):
                        string = string.replace(characters[x],"")# \t 삭제한 row[0] 을 string 변수에 저장
                        
                        cnt_list=cnt-16            #wind_realdata1[0][0]을 자동으로 카운트해주기 위해
                
                        wind_realdata1[cnt_list][0]=string #wind_realdata1[n][0]에 있는 리스트 요소를 string으로 바꾸기 위함 
            f6.close()
            #__________________________________________________   

            # 필요한 타이틀만 남겨두기
            #-------------------------------------------------
            cnt_1=0
            cnt_2=9
            for p in wind_realdata1:
                for x in range(5):
                    try:
                        del wind_realdata1[cnt_1][cnt_2]
                    except IndexError:
                        continue
                    cnt_2-=1
                cnt_2=9
                cnt_1+=1
                
            cnt_1=0   

            for p in wind_realdata1:

                try:
                    del wind_realdata1[cnt_1][0]
                        
                except IndexError:
                    continue
                cnt_1+=1
                
            cnt_1=0
            
            for p in wind_realdata1:

                try:
                    del wind_realdata1[cnt_1][0]
                    del wind_realdata1[cnt_1][0]   
                except IndexError:
                    continue
                cnt_1+=1
            #__________________________________________________   

            # 저장된 데이터에서 비어있는 쓰레기값 제거
            #-------------------------------------------------
            lendata=len(wind_realdata1)-7

            for p1 in range(7):
                try:
                    del wind_realdata1[lendata]
                except IndexError:
                        continue


            sum_realdata1= [[0 for col in range(8)] for row in range(len(temperature_realdata1))]
        
            

            cnt_1=0

            for p in sum_realdata1: 
                for z in range(8):
                    if z<5:
                        sum_realdata1[cnt_1][z]=temperature_realdata1[cnt_1][z]
                    elif z==5:
                        try:
                            sum_realdata1[cnt_1][z]=rain_realdata1[cnt_1][z-z]
                        except IndexError:
                                continue
                    elif z==6:
                        try:
                            sum_realdata1[cnt_1][z]=wind_realdata1[cnt_1][z-z]
                        except IndexError:
                                continue
                    else:
                        try:
                            sum_realdata1[cnt_1][z]=wind_realdata1[cnt_1][z-(z-1)]
                        except IndexError:
                                continue
                cnt_1+=1

        
            cnt_1=0
            z=0
            
            
            
            
            if loacation_name =='서울':
                
                sum2_data1= [[0 for col in range(8)] for row in range(len(temperature_realdata1))]
                
                for p in sum2_data1: 
                    for z in range(8):
                        
                        try:
                            sum2_data1[cnt_1][0]=sum_realdata1[cnt_1][1]
                            sum2_data1[cnt_1][1]=sum_realdata1[cnt_1][0]
                        except IndexError:
                                continue
                        if z>=2:
                            sum2_data1[cnt_1][z]=sum_realdata1[cnt_1][z]

                    cnt_1+=1
                
            elif loacation_name =='부산':
                
                sum2_data2= [[0 for col in range(8)] for row in range(len(temperature_realdata1))]
                p=0
                z=0
                cnt_1=0
                for p in sum2_data2: 
                    for z in range(8):
                        
                        try:
                            sum2_data2[cnt_1][0]=sum_realdata1[cnt_1][1]
                            sum2_data2[cnt_1][1]=sum_realdata1[cnt_1][0]
                        except IndexError:
                                continue
                        if z>=2:
                            sum2_data2[cnt_1][z]=sum_realdata1[cnt_1][z]

                    cnt_1+=1
                

                

            elif loacation_name =='대구':
                sum2_data3= [[0 for col in range(8)] for row in range(len(temperature_realdata1))]
                p=0
                z=0
                cnt_1=0
                for p in sum2_data3: 
                    for z in range(8):
                        
                        try:
                            sum2_data3[cnt_1][0]=sum_realdata1[cnt_1][1]
                            sum2_data3[cnt_1][1]=sum_realdata1[cnt_1][0]
                        except IndexError:
                                continue
                        if z>=2:
                            sum2_data3[cnt_1][z]=sum_realdata1[cnt_1][z]

                    cnt_1+=1


            


            elif loacation_name =='광주':
                sum2_data5= [[0 for col in range(8)] for row in range(len(temperature_realdata1))]
                p=0
                z=0
                cnt_1=0
                for p in sum2_data5: 
                    for z in range(8):
                        
                        try:
                            sum2_data5[cnt_1][0]=sum_realdata1[cnt_1][1]
                            sum2_data5[cnt_1][1]=sum_realdata1[cnt_1][0]
                        except IndexError:
                                continue
                        if z>=2:
                            sum2_data5[cnt_1][z]=sum_realdata1[cnt_1][z]

                    cnt_1+=1

            elif loacation_name =='대전':
                sum2_data6= [[0 for col in range(8)] for row in range(len(temperature_realdata1))]
                p=0
                z=0
                cnt_1=0
                for p in sum2_data6: 
                    for z in range(8):
                        
                        try:
                            sum2_data6[cnt_1][0]=sum_realdata1[cnt_1][1]
                            sum2_data6[cnt_1][1]=sum_realdata1[cnt_1][0]
                        except IndexError:
                                continue
                        if z>=2:
                            sum2_data6[cnt_1][z]=sum_realdata1[cnt_1][z]

                    cnt_1+=1

            



                    


sum_weather=[sum_data1+sum_data2+sum_data3+sum_data5+sum_data6+sum2_data1+sum2_data2+sum2_data3+sum2_data5+sum2_data6]


for num in range(len(sum_weather[0])): # 리스트 요소들을 str에서 float로 바꿈
    for z in range(8):
        if  z ==2:
            if sum_weather[0][num][z] =='0':
                sum_weather[0][num][z]=0.0
            elif sum_weather[0][num][z] == '':
                sum_weather[0][num][z]=0.0
            sum_weather[0][num][z]=float(sum_weather[0][num][z])
            
        
        elif z==3:
            if sum_weather[0][num][z] =='0':
                sum_weather[0][num][z]=0.0
            elif sum_weather[0][num][z] == '':
                sum_weather[0][num][z]=0.0
            sum_weather[0][num][z]=float(sum_weather[0][num][z])
        elif z==4:
            if sum_weather[0][num][z] =='0':
                sum_weather[0][num][z]=0.0
            elif sum_weather[0][num][z] == '':
                sum_weather[0][num][z]=0.0
            sum_weather[0][num][z]=float(sum_weather[0][num][z])
        elif z==4:
            if sum_weather[0][num][z] =='0':
                sum_weather[0][num][z]=0.0
            elif sum_weather[0][num][z] == '':
                sum_weather[0][num][z]=0.0
            sum_weather[0][num][z]=float(sum_weather[0][num][z])
        elif z==5:
            if sum_weather[0][num][z] =='0':
                sum_weather[0][num][z]=0.0
            elif sum_weather[0][num][z] == '':
                sum_weather[0][num][z]=0.0
            sum_weather[0][num][z]=float(sum_weather[0][num][z])
         
        elif z==6:
            if sum_weather[0][num][z] =='0':
                sum_weather[0][num][z]=0.0
            elif sum_weather[0][num][z] == '':
                sum_weather[0][num][z]=0.0
            sum_weather[0][num][z]=float(sum_weather[0][num][z])
        elif z==7:
            
            if sum_weather[0][num][z] =='0':
                sum_weather[0][num][z]=0.0
            elif sum_weather[0][num][z] == '':
                sum_weather[0][num][z]=0.0
            sum_weather[0][num][z]=float(sum_weather[0][num][z])

lastlist=[[0 for col in range(len(sum_weather[0][0]))] for row in range(len(sum_weather[0]))]


for num in range(len(sum_weather[0])): # sum_weather의 [] 를 하나 제거함
    for z in range(8):
        try:
            lastlist[num][z]=sum_weather[0][num][z]
            
            
        except:
            continue
            







os.environ["PATH"] = LOCATION + ";" + os.environ["PATH"] 
cursor = conn.cursor()

cursor.execute("delete WEATHER")
conn.commit()

k=0
z=0

for k in range(len(lastlist)):
    
    sql="insert into weather values(WEATHER_CODE.NEXTVAL,to_date(:WEATHER_PERIOD,'YYYY-MM-DD'), :WEATHER_AREA, :WEATHER_AVER_TEM, :WEATHER_HIGH_TEM, :WEATHER_LOW_TEM,:WEATHER_PRECIPITATION,:WEATHER_AVER_WIND,:WEATHER_HIGH_WIND)"
    data=[lastlist[k][0], lastlist[k][1], lastlist[k][2],lastlist[k][3],lastlist[k][4],lastlist[k][5],lastlist[k][6],lastlist[k][7]]

    cursor.execute(sql,data)
    conn.commit()
cursor.close()
conn.close()
print('기상데이터 크기 :',len(sum_weather[0]))
print("기상데이터 정제 끝")

"""
weather 테이블 sql문


CREATE TABLE "WEATHER"
   (	"WEATHER_CODE" INTEGER, 
    "WEATHER_PERIOD" DATE,
    "WEATHER_AREA" VARCHAR2(30 BYTE),
    "WEATHER_AVER_TEM" NUMBER(5,2),
    "WEATHER_HIGH_TEM" NUMBER(5,2),
    "WEATHER_LOW_TEM" VARCHAR2(30 BYTE),
    "WEATHER_PRECIPITATION" NUMBER(10,2),
    "WEATHER_AVER_WIND" NUMBER(10,2),
    "WEATHER_HIGH_WIND" NUMBER(10,2)
   );
   
   
제약조건

ALTER TABLE "WEATHER" ADD PRIMARY KEY ("WEATHER_CODE");

"""
# Out:
# 기상데이터 크기 : 1835
# 기상데이터 정제 끝
# '\nweather 테이블 sql문\n\n\nCREATE TABLE "WEATHER"\n   (\t"WEATHER_CODE" INTEGER, \n    "WEATHER_PERIOD" DATE,\n    "WEATHER_AREA" VARCHAR2(30 BYTE),\n    "WEATHER_AVER_TEM" NUMBER(5,2),\n    "WEATHER_HIGH_TEM" NUMBER(5,2),\n    "WEATHER_LOW_TEM" VARCHAR2(30 BYTE),\n    "WEATHER_PRECIPITATION" NUMBER(10,2),\n    "WEATHER_AVER_WIND" NUMBER(10,2),\n    "WEATHER_HIGH_WIND" NUMBER(10,2)\n   );\n   \n   \n제약조건\n\nALTER TABLE "WEATHER" ADD PRIMARY KEY ("WEATHER_CODE");\n\n'
